# %% [markdown]
# # Scenario
# This is a continuation of the analysis you’re doing alongside Mandisa Nkosi to inform decision-making in politics, first introduced in 3.1.5 Practical activity: Create and merge the DataFrames.
#
# The political party is considering running advertisements with some provoking messages, but they need to ensure the content is suitable for the audiences watching the films. The data Mandisa is working with includes content ratings (in the Age column) that Mandisa can use to organise the DataFrame.
#
# # Objective
#
# Your objective at this stage is to organise the data by:
#
# the film release date and content rating
# the title of movies, the directors, and genres by content rating
# the title of movies, the released year, and the language by content rating
# Netflix screened movies based on language, runtime, and country
# the title of movies, specified language, potential runtime, and genres by content rating.
# You’ll need to use the pivot() function to create pivot tables for each description. More specifically, you’ll:
#
# create a DataFrame for each description
# employ the pivot() function on the merged and original DataFrames
# specify the necessary parameters for the pivot() function.

# %% [markdown]
# # Importing the data and creating the relevant DataFrames

# %%
# Import Pandas.
import pandas as pd

# Load the Excel data using pd.read_excel.
movies = pd.read_excel('movies_merge.xlsx')

# Load the csv data using pd.read_csv.
ott = pd.read_csv('ott_merge.csv')

# Data imported correctly?
print(movies.columns)
print(movies.shape)
print(ott.columns)
print(ott.shape)

# Merge the two DataFrames.
mov_ott = pd.merge(movies, ott, how='left', on = 'ID')

# DataFrames merged correctly?
print(mov_ott.columns)
print(mov_ott.shape)
# Out:
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime'],
#       dtype='object')
# (16744, 11)
# Index(['ID', 'Netflix', 'Hulu', 'Prime Video', 'Disney+'], dtype='object')
# (16744, 5)
# Index(['ID', 'Title', 'Year', 'Age', 'IMDb', 'Rotten Tomatoes', 'Directors',
#        'Genres', 'Country', 'Language', 'Runtime', 'Netflix', 'Hulu',
#        'Prime Video', 'Disney+'],
#       dtype='object')
# (16744, 15)

# %%
#view the new DataFrame

mov_ott
# Out:
#           ID                           Title  Year  Age  IMDb  \
# 0          1                       Inception  2010  13+   8.8
# 1          2                      The Matrix  1999  18+   8.7
# 2          3          Avengers: Infinity War  2018  13+   8.5
# 3          4              Back to the Future  1985   7+   8.5
# 4          5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...      ...                             ...   ...  ...   ...
# 16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740  16741                  The Poof Point  2001   7+   4.7
# 16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743  16744                In Beaver Valley  1950  NaN   NaN
#
#        Rotten Tomatoes                       Directors  \
# 0                 0.87               Christopher Nolan
# 1                 0.87  Lana Wachowski,Lilly Wachowski
# ...

# %% [markdown]
# # 1- The film release date and content rating

# %%
# Determine movies per year and age group.
movies.pivot(index='Title', columns='Age', 
             values='Year')
# Out:
# Age                                NaN     13+  16+     18+      7+  all
# Title
# Inception                          NaN  2010.0  NaN     NaN     NaN  NaN
# The Matrix                         NaN     NaN  NaN  1999.0     NaN  NaN
# Avengers: Infinity War             NaN  2018.0  NaN     NaN     NaN  NaN
# Back to the Future                 NaN     NaN  NaN     NaN  1985.0  NaN
# The Good, the Bad and the Ugly     NaN     NaN  NaN  1966.0     NaN  NaN
# ...                                ...     ...  ...     ...     ...  ...
# The Ghosts of Buxley Hall       1980.0     NaN  NaN     NaN     NaN  NaN
# The Poof Point                     NaN     NaN  NaN     NaN  2001.0  NaN
# Sharks of Lost Island           2013.0     NaN  NaN     NaN     NaN  NaN
# Man Among Cheetahs              2017.0     NaN  NaN     NaN     NaN  NaN
# In Beaver Valley                1950.0     NaN  NaN     NaN     NaN  NaN
#
# [16744 rows x 6 columns]

# %% [markdown]
# # 2- the title of movies, the directors, and genres by content rating

# %%
# Determine the title of movies, director, and genres by content rating

movies.pivot(index='Title', columns='Age', 
             values=['Directors', 'Genres'])
# Out:
#                                            Directors                           \
# Age                                              NaN                      13+
# Title
# Inception                                        NaN        Christopher Nolan
# The Matrix                                       NaN                      NaN
# Avengers: Infinity War                           NaN  Anthony Russo,Joe Russo
# Back to the Future                               NaN                      NaN
# The Good, the Bad and the Ugly                   NaN                      NaN
# ...                                              ...                      ...
# The Ghosts of Buxley Hall               Bruce Bilson                      NaN
# The Poof Point                                   NaN                      NaN
# Sharks of Lost Island                   Neil Gelinas                      NaN
# Man Among Cheetahs              Richard Slater-Jones                      NaN
# ...

# %% [markdown]
# # 3-the title of movies, the released year, and the language by content rating

# %%
# Determine movies, year, and language per age group.

movies.pivot(index='Title', columns='Age', 
             values=['Year', 'Language'])
# Out:
#                                 Year                             Language  \
# Age                              NaN   13+  16+   18+    7+  all      NaN
# Title
# Inception                        NaN  2010  NaN   NaN   NaN  NaN      NaN
# The Matrix                       NaN   NaN  NaN  1999   NaN  NaN      NaN
# Avengers: Infinity War           NaN  2018  NaN   NaN   NaN  NaN      NaN
# Back to the Future               NaN   NaN  NaN   NaN  1985  NaN      NaN
# The Good, the Bad and the Ugly   NaN   NaN  NaN  1966   NaN  NaN      NaN
# ...                              ...   ...  ...   ...   ...  ...      ...
# The Ghosts of Buxley Hall       1980   NaN  NaN   NaN   NaN  NaN  English
# The Poof Point                   NaN   NaN  NaN   NaN  2001  NaN      NaN
# Sharks of Lost Island           2013   NaN  NaN   NaN   NaN  NaN  English
# Man Among Cheetahs              2017   NaN  NaN   NaN   NaN  NaN  English
# In Beaver Valley                1950   NaN  NaN   NaN   NaN  NaN  English
# ...

# %% [markdown]
# # 4-Netflix-screened movies based on language, runtime, and country

# %%
# Determine the language, runtime, and country of movies screened by Netflix.
mov_ott.pivot(index='Title', columns='Netflix', 
              values=['Language', 'Runtime', 'Country'])
# Out:
#                                                Language          Runtime  \
# Netflix                                               0        1       0
# Title
# Inception                       English,Japanese,French      NaN   148.0
# The Matrix                                      English      NaN   136.0
# Avengers: Infinity War                          English      NaN   149.0
# Back to the Future                                  NaN  English     NaN
# The Good, the Bad and the Ugly                  Italian      NaN   161.0
# ...                                                 ...      ...     ...
# The Ghosts of Buxley Hall                       English      NaN   120.0
# The Poof Point                                  English      NaN    90.0
# Sharks of Lost Island                           English      NaN     NaN
# Man Among Cheetahs                              English      NaN     NaN
# In Beaver Valley                                    NaN  English     NaN
#
# ...

# %% [markdown]
# # The title of movies, specified language, potential runtime, and genres by content rating

# %%
# Determine the movies, language, runtime, and genres per age group.
mov_ott.pivot(index='Title', columns='Age', 
              values=['Language', 'Runtime','Genres'])
# Out:
#                                Language                                \
# Age                                 NaN                      13+  16+
# Title
# Inception                           NaN  English,Japanese,French  NaN
# The Matrix                          NaN                      NaN  NaN
# Avengers: Infinity War              NaN                  English  NaN
# Back to the Future                  NaN                      NaN  NaN
# The Good, the Bad and the Ugly      NaN                      NaN  NaN
# ...                                 ...                      ...  ...
# The Ghosts of Buxley Hall       English                      NaN  NaN
# The Poof Point                      NaN                      NaN  NaN
# Sharks of Lost Island           English                      NaN  NaN
# Man Among Cheetahs              English                      NaN  NaN
# In Beaver Valley                English                      NaN  NaN
#
# ...
